# %% [markdown]
# # Plot Speed-Accuracy Tradeoff (SAT) Curve
# Step 3. in
# 1. Generate Nosaic MNIST (`python make_nmnist.py`).
# 2. Extract and save features in TFRecords format (save_featureTFR_nmnist.ipynb).
# 3. Plot SAT curve (plot_SAT_curve.ipynb)

# %%
from __future__ import absolute_import, division, print_function

import os, sys, glob
from itertools import zip_longest
import optuna, sqlite3
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from datasets.data_processing import read_tfrecords_nosaic_mnist,\
    decode_feat, sequential_slice
from models.backbones_ti import LSTMModelLite
from models.losses import get_loss_lstm
from utils.misc import load_yaml, set_gpu_devices, fix_random_seed
from utils.performance_metrics import multiplet_sequential_confmx,\
    binary_llr_sequential_confmx, confmx_to_metrics, seqconfmx_to_list_metrics,\
    list_metrics_to_list_bac, dict_confmx_to_dict_metrics, run_truncated_sprt,\
    calc_binary_llrs, binary_avescr_test, binary_np_test

# %%
# Which GPU to be used
set_gpu_devices(0)

# %% [markdown]
# # User-defined params

# %%
# Paths
order_sprt = 1
if order_sprt == 1:
    name_model = "./example_ckpts/temporal_integrator/LSTM_1st_order_SPRT-TANDEM"
if order_sprt == 10:
    name_model = "./example_ckpts/temporal_integrator/LSTM_10th_order_SPRT-TANDEM"

num_plot = 100 # how many thresholds to be used to plot SAT curve
num_traj = 100 # how many sequential data points to be used to plot LLR trajectories

tfr_train = "/data/t-miyagawa/nosaic_mnist/nosaic_mnist_feat_train.tfrecords" # not used but necessary for convenience
tfr_test = "/data/t-miyagawa/nosaic_mnist/nosaic_mnist_feat_test.tfrecords"
duration = 20
feat_dim = 128
batch_size = 200 # must be a divisor of the num of test data points
nb_cls = 2
width_lstm = feat_dim # make sure this is consistent with ckpt
dropout = 0.
activation = "tanh" 
    # (maybe) make sure activation is consistent with ckpt. 
    # tanh is the default in LSTMModelLite and LSTMModel

# %% [markdown]
# # Start calc

# %%
# Generate Thresholds for SPRT
list_alpha = np.logspace(logspace_start, np.log10(0.5), num_plot, base=10, endpoint=False)
#list_alpha = np.logspace(-40, np.log10(0.5), num_plot, base=10, endpoint=False)
list_beta = list_alpha

thresh = [np.log(list_beta/(1-list_alpha)), np.log((1-list_beta)/list_alpha)]
if not ( np.any(thresh[1] >= thresh[0]) and np.any(thresh[1] * thresh[0] < 0) ):
   raise ValueError(
       "thresh must be thresh[1] >= thresh[0] and thresh[1] * thresh[0] < 0. Now thresh = {}".format(thresh))
thresh
# Out:
# [array([-46.05170186, -45.59811631, -45.14453077, -44.69094522,
#         -44.23735967, -43.78377413, -43.33018858, -42.87660303,
#         -42.42301749, -41.96943194, -41.51584639, -41.06226085,
#         -40.6086753 , -40.15508975, -39.7015042 , -39.24791866,
#         -38.79433311, -38.34074756, -37.88716202, -37.43357647,
#         -36.97999092, -36.52640538, -36.07281983, -35.61923428,
#         -35.16564874, -34.71206319, -34.25847764, -33.8048921 ,
#         -33.35130655, -32.897721  , -32.44413546, -31.99054991,
#         -31.53696436, -31.08337882, -30.62979327, -30.17620772,
#         -29.72262218, -29.26903663, -28.81545108, -28.36186553,
#         -27.90827999, -27.45469444, -27.00110889, -26.54752335,
#         -26.0939378 , -25.64035225, -25.18676671, -24.73318116,
#         -24.27959561, -23.82601007, -23.37242452, -22.91883897,
#         -22.46525343, -22.01166788, -21.55808233, -21.10449679,
#         -20.65091124, -20.19732569, -19.74374014, -19.29015459,
#         -18.83656905, -18.3829835 , -17.92939794, -17.47581239,
#         -17.02222682, -16.56864125, -16.11505567, -15.66147007,
#         -15.20788443, -14.75429874, -14.30071297, -13.84712707,
#         -13.39354097, -12.93995454, -12.48636762, -12.0327799 ,
#         -11.57919094, -11.12560003, -10.67200603, -10.21840717,
#          -9.76480068,  -9.31118217,  -8.85754473,  -8.4038775 ,
#          -7.95016339,  -7.49637544,  -7.04247125,  -6.58838397,
#          -6.13400821,  -5.67917765,  -5.22362937,  -4.76694676,
#          -4.3084671 ,  -3.84712963,  -3.38121994,  -2.90792385,
#          -2.4225059 ,  -1.91667036,  -1.37488176,  -0.76448646]),
#  array([46.05170186, 45.59811631, 45.14453077, 44.69094522, 44.23735967,
#         43.78377413, 43.33018858, 42.87660303, 42.42301749, 41.96943194,
#         41.51584639, 41.06226085, 40.6086753 , 40.15508975, 39.7015042 ,
#         39.24791866, 38.79433311, 38.34074756, 37.88716202, 37.43357647,
#         36.97999092, 36.52640538, 36.07281983, 35.61923428, 35.16564874,
#         34.71206319, 34.25847764, 33.8048921 , 33.35130655, 32.897721  ,
#         32.44413546, 31.99054991, 31.53696436, 31.08337882, 30.62979327,
#         30.17620772, 29.72262218, 29.26903663, 28.81545108, 28.36186553,
#         27.90827999, 27.45469444, 27.00110889, 26.54752335, 26.0939378 ,
#         25.64035225, 25.18676671, 24.73318116, 24.27959561, 23.82601007,
#         23.37242452, 22.91883897, 22.46525343, 22.01166788, 21.55808233,
#         21.10449679, 20.65091124, 20.19732569, 19.74374014, 19.29015459,
#         18.83656905, 18.3829835 , 17.92939794, 17.47581239, 17.02222682,
#         16.56864125, 16.11505567, 15.66147007, 15.20788443, 14.75429874,
#         14.30071297, 13.84712707, 13.39354097, 12.93995454, 12.48636762,
#         12.0327799 , 11.57919094, 11.12560003, 10.67200603, 10.21840717,
#          9.76480068,  9.31118217,  8.85754473,  8.4038775 ,  7.95016339,
#          7.49637544,  7.04247125,  6.58838397,  6.13400821,  5.67917765,
#          5.22362937,  4.76694676,  4.3084671 ,  3.84712963,  3.38121994,
#          2.90792385,  2.4225059 ,  1.91667036,  1.37488176,  0.76448646])]

# %%
# Load data
##################################
# Reed tfr and make 
parsed_image_dataset_train, parsed_image_dataset_valid, parsed_image_dataset_test = \
    read_tfrecords_nosaic_mnist(
        record_file_train=tfr_train, 
        record_file_test=tfr_test, 
        batch_size=batch_size, 
        shuffle_buffer_size=2000)

# Model
##################################
model = LSTMModelLite(
    nb_cls=nb_cls, 
    width_lstm=width_lstm, 
    dropout=dropout, 
    activation=activation) 

# Restore parameters
#################################
ckpt = tf.train.Checkpoint(net=model)
ckpt_manager_restore = tf.train.CheckpointManager(ckpt,
    name_model, max_to_keep=3)
ckpt.restore(ckpt_manager_restore.latest_checkpoint)
print("Restored latest model\n{}".format(
    ckpt_manager_restore.latest_checkpoint)) 

# Evaluaton loop
##################################
for iter_b, feats in enumerate(parsed_image_dataset_test):
    cnt = iter_b + 1

    # Decode features and binarize classification labels
    x_batch, y_batch = decode_feat(feats, duration, feat_dim, 
        dtype_feat=tf.float32, dtype_label=tf.int32)

    # Calc logits 
    if iter_b == 0:
        # Calc loss
        _, logits_tmp = get_loss_lstm(model, x_batch,y_batch,
            training=False, order_sprt=order_sprt)
        logits_all = logits_tmp
        labels_all = y_batch

    else:
        _, logits_tmp = get_loss_lstm(model, x_batch, y_batch, 
            training=False, order_sprt=order_sprt)
        logits_all = tf.concat([logits_all, logits_tmp], 0)
        labels_all = tf.concat([labels_all, y_batch], 0)

    # Verbose
    if ((iter_b+1)%10 == 0) or (iter_b == 0):
        sys.stdout.write("\rEvaluation Iter: {:3d}".format(iter_b+1))
        sys.stdout.flush()
        
# run truncated SPRT
dict_confmx_sprt, dict_mean_hittimes, dict_var_hittimes,\
    dict_truncate_rates = run_truncated_sprt(
        list_alpha,
        list_beta, 
        logits_all, 
        labels_all, 
        verbose=False)
dict_metrics_sprt = dict_confmx_to_dict_metrics(dict_confmx_sprt)

# Balanced accuracy, mean hitting time, stdev of hitting times 
list_mht = []
list_stdevht = []
list_bac = []
for iter_num, key in enumerate(dict_metrics_sprt.keys()):
    # Verbose
    if (iter_num == 0) or ((iter_num + 1) % 50 == 0) or ((iter_num + 1) == len(dict_metrics_sprt)):
        print("Thresh Iter {}/{} {}".format(iter_num + 1, len(dict_metrics_sprt), key))

    metrics_test = dict_metrics_sprt[key]
    list_bac.append(float(metrics_test["BAC"][0]))
    list_mht.append(float(dict_mean_hittimes[key]))
    list_stdevht.append(float(np.sqrt(dict_var_hittimes[key])))
# Out:
# W0525 07:31:48.745329 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer
# W0525 07:31:48.747076 139669605709568 util.py:144] Unresolved object in checkpoint: (root).step
# W0525 07:31:48.748557 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer.iter
# W0525 07:31:48.750331 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0525 07:31:48.751834 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0525 07:31:48.753376 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer.decay
# W0525 07:31:48.754881 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer.weight_decay
# W0525 07:31:48.756335 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.kernel
# W0525 07:31:48.757961 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.recurrent_kernel
# W0525 07:31:48.759473 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.bias
# W0525 07:31:48.761108 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.input_gate_peephole_weights
# W0525 07:31:48.762550 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.forget_gate_peephole_weights
# W0525 07:31:48.764102 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.lstm_cell.output_gate_peephole_weights
# W0525 07:31:48.765669 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.bn_logit.gamma
# W0525 07:31:48.767087 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.bn_logit.beta
# W0525 07:31:48.768477 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.fc_logit.kernel
# W0525 07:31:48.769937 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.kernel
# W0525 07:31:48.771444 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.recurrent_kernel
# W0525 07:31:48.772693 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.bias
# W0525 07:31:48.774095 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.input_gate_peephole_weights
# W0525 07:31:48.775404 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.forget_gate_peephole_weights
# W0525 07:31:48.776564 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.lstm_cell.output_gate_peephole_weights
# W0525 07:31:48.777708 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.bn_logit.gamma
# W0525 07:31:48.778974 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.bn_logit.beta
# W0525 07:31:48.780274 139669605709568 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.fc_logit.kernel
# W0525 07:31:48.781632 139669605709568 util.py:152] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Restored latest model
# /data/t-miyagawa/sprt/nosaic_mnist/ckptlogs/TI_19thO_stat_stat/TI__20200406_023820415/ckpt_step4800_mbac0.97125-16
# Evaluation Iter:  50Thresh Iter 1/100 thresh=-12.9400,12.9400
# Thresh Iter 50/100 thresh=-12.4864,12.4864
# Thresh Iter 100/100 thresh=-43.7838,43.7838

# %% [markdown]
# # 1. Plot PEC (Performance-Earliness Curve)

# %%
# Start plotting SP curve
######################################
# Parameters
x = list_mht
y = list_bac
name_dataset = "Nosaic MNIST"

title = "Performance-Earliness Curve\ndata={}, order={}".format(name_dataset, order_sprt)
xlabel = "Mean Hitting Time"
ylabel = "Balanced Accuracy"

# Plot
plt.rcParams["font.size"] = 20
plt.figure(figsize=(10,7))

plt.scatter(
    x, y, 
    s=10, 
    color="red", 
    marker='o', 
    vmin=None, 
    vmax=None, 
    alpha=None, 
    linewidths=None,
    edgecolors=None
    )

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.xscale("log")
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
#plt.legend()
plt.title(title)
plt.xticks([i for i in range(1, duration + 1)])
plt.xlim(0.7, duration+0.3)
#plt.xlim(19.99, 20)
#plt.ylim(0.75, 1.005)
plt.tight_layout()

# Save figure
#plt.savefig(***) ###

# %% [markdown]
# ## 1-1. NPT (Neyman-Pearson Test)

# %%
list_thresh_np = [0., 1., 10., -1, -10]

title = "Performance-Earliness Curve\ndata=Nosaic MNIST, order={}".format(order_sprt)
label = "SPRT"
xlabel = "Hitting Time"
ylabel = "Balanced Accuracy"

plt.rcParams["font.size"] = 20
plt.figure(figsize=(10,7))

for thresh_np in list_thresh_np:
    list_nplen = [i+1 for i in range(duration)]
    list_npbac = []
    llrs_all = calc_binary_llrs(logits_all)

    # NP test
    for iter_nplen in list_nplen:
        confmx = binary_np_test(
                llrs_all, 
                labels_all,
                length=iter_nplen,
                thresh=thresh_np)

        list_npbac.append(confmx_to_metrics(confmx)["BAC"][0].numpy())


    # Plot NPT vs SPRT
    ###############################
    # Parameters
    x = list_mht
    y = list_bac


    # Plot NPT
    plt.scatter(
        list_nplen, list_npbac, 
        s=60, 
        #color="blue", 
        marker='x', 
        vmin=None, 
        vmax=None, 
        alpha=None, 
        linewidths=None,
        edgecolors=None,
        label="thresh={}".format(thresh_np)
        )

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.xscale("log")
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
plt.legend()
plt.title(title)
plt.xticks([i for i in range(1, duration + 1)])
plt.xlim(0.7, 20.3)
#plt.xlim(1.9, 2.1)
#plt.ylim(0.75, 1.005)
#plt.ylim(0.8, 0.89)
plt.tight_layout()

# Save figure
#plt.savefig(***) ###

# %% [markdown]
# ## 1-2. SPRT vs NPT

# %%
# Parameters
thresh = 0.
list_nplen = [i+1 for i in range(duration)]
list_npbac = []
llrs_all = calc_binary_llrs(logits_all)

# NP test
for iter_nplen in list_nplen:
    confmx = binary_np_test(
            llrs_all, 
            labels_all,
            length=iter_nplen,
            thresh=thresh)

    list_npbac.append(confmx_to_metrics(confmx)["BAC"][0].numpy())

    
# Plot NPT vs SPRT
###############################
# Parameters
x = list_mht
y = list_bac
title = "Performance-Earliness Curve\ndata=Nosaic MNIST, order={}".format(order_sprt)
label = "SPRT"
xlabel = "Mean Hitting Time"
ylabel = "Balanced Accuracy"

plt.rcParams["font.size"] = 20
plt.figure(figsize=(10,7))

# Plot SPRT
plt.scatter(
    x, y, 
    s=10, 
    color="red", 
    marker='o', 
    vmin=None, 
    vmax=None, 
    alpha=None, 
    linewidths=None,
    edgecolors=None,
    label=label
    )

# Plot NPT
plt.scatter(
    list_nplen, list_npbac, 
    s=10, 
    color="blue", 
    marker='o', 
    vmin=None, 
    vmax=None, 
    alpha=None, 
    linewidths=None,
    edgecolors=None,
    label="NPT with thresh {}".format(thresh)
    )

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.xscale("log")
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
plt.legend()
plt.title(title)
plt.xticks([i for i in range(1, duration + 1)])
#plt.xlim(0.7, 20.3)
plt.xlim(19,  20.3)
plt.ylim(0.75, 1.005)
plt.tight_layout()

# Save figure
# plt.savefig(***) ###

# %% [markdown]
# # 2. Plot PEC with Standard Deviation

# %%
# Start plotting SP curve with variance
######################################
# Parameters
x = list_mht
y = list_bac
x_err = list_stdevht
title = "Performance-Earliness Curve with Stdev\ndata=Nosaic MNIST, order={}".format(order_sprt)
label = "label"
xlabel = "Mean Hitting Time"
ylabel = "Balanced Accuracy"

# Plot
plt.rcParams["font.size"] = 20
plt.figure(figsize=(10,7))

plt.errorbar(
    x, y, 
    xerr = x_err, 
    capsize=3, 
    fmt='o', 
    markersize=2, 
    ecolor='black', 
    markeredgecolor = "black", 
    color='red',
    elinewidth=0.5)

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.xscale("log")
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
#plt.legend()
plt.title(title)
plt.tight_layout()
plt.xticks([i for i in range(1, duration + 4)])
plt.xlim(0., 23.3)
plt.ylim(0.75, 1.005)

# Save figure
# plt.savefig(***) ###
# Out:
# (0.75, 1.005)

# %% [markdown]
# # 3. Plot Trajectories of LLRs

# %%
# Start plotting trajectory
######################################
idx_perm = np.random.permutation(labels_all.shape[0])[:num_traj]
llrs_plot = calc_binary_llrs(logits_all.numpy()[idx_perm])
labels_plot = labels_all.numpy()[idx_perm]

# Parameters
title = "Example LLR trajectory, data: NMNIST, order: {}".format(order_sprt)
xlabel = "Frame"
ylabel = "Log-likelihood ratio"

plt.rcParams["font.size"] = 20
plt.rcParams["font.size"] = 25
#plt.figure(figsize=(10,7))
plt.figure(figsize=(13,8)) ################
x = [i for i in range(0, duration+1)]
fl1 = True
fl0 = True
for llrs, label in zip(llrs_plot, labels_plot):
    y = np.append(0, llrs)
    if label == 1:
        color = "red"
    else:
        color = "blue"

    # Plot
    if fl1 and (label == 1):
        plot_label = "class1"
        fl1 = False
    elif fl0 and (label == 0):
        plot_label = "class0"
        fl0 = False
    else:
        plot_label = None
    plt.plot(
        x, y, 
        color=color, 
        marker='o', 
        linewidth=1, 
        markersize=0,
        label=plot_label
        )
    cnt += 1

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.yscale('symlog')
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
#plt.legend()
plt.title(title)
plt.xticks([i for i in range(0, duration + 1)])
plt.xlim(-0.1, 20.1)
#plt.ylim(-25, 30)
#plt.ylim(-250, 150)
#plt.ylim(-50, 50)

plt.tight_layout()

# Save figure 
plt.savefig(
    "/data/t-miyagawa/sprt/nosaic_mnist/graphs/experiment_20200525_FairCopySvg/Traj_NMNIST_19th_13x8_v1_20200525.svg", 
    format="svg", 
    dpi=1200) ##################

# %% [markdown]
# # 4. Plot PEC with Iines

# %%
# Start plotting SP curve
######################################
# Parameters
x = np.array(list_mht)
y = np.array(list_bac)
sort_idx = np.argsort(x)
x = x[sort_idx]
y = y[sort_idx]
name_dataset = "Nosaic MNIST"

title = "Performance-Earliest Curve\ndata={}, order={}".format(name_dataset, order_sprt)
xlabel = "Mean Hitting Time"
ylabel = "Balanced Accuracy"

# Plot
plt.rcParams["font.size"] = 20
plt.figure(figsize=(10,7))

plt.plot(
    x, y, 
    marker="x", 
    markersize=5, 
    markeredgewidth=1, 
    markeredgecolor="red",
    markerfacecolor="lightblue")

plt.xlabel(xlabel)
plt.ylabel(ylabel)        
#plt.ylabel('Test {}, cls={}'.format(iter_metric, iter_cls), fontsize=20)
#plt.xscale("log")
plt.grid(True)
#plt.legend(bbox_to_anchor=(0.15, 0, 0.4, 0.9))
#plt.legend()
plt.title(title)
plt.xticks([i for i in range(1, duration + 1)])
plt.xlim(0.7, duration+0.3)
#plt.xlim(19.99, 20)
#plt.ylim(0.75, 1.005)
plt.tight_layout()

# Save figure
#plt.savefig(***) ###
